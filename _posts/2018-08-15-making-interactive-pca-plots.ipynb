# %% [markdown]
# # Making interactive PCA plots
#
# ## Using the `bokeh` library
#
# In population genetics, we frequently make PCA plots- they are helpful to identify population structure, as well as performing quality control. It's often of biological or technical interest (or concern!) if a sample doesn't cluster with samples that we expect it to. A limitation of most plots is that it is awkward to work out what the sample ID is of an outlier.
#
# Another limitation of PCA plots is that samples fall into very dense clusters, making it difficult to see exactly what is going on, with some samples completely masking others.
#
# Interactive plots solve both of these issues. A simple mouse over reveals sample ID, and pertinent information about the sample- and we can pan and zoom in on densely populated regions.
#
# This isn't a PCA tutorial, in fact the PCA analysis performed here was taken from Alistair Miles' excellent blog post [Fast PCA](http://alimanfoo.github.io/2015/09/28/fast-pca.html). The coordinates and percent variance explained values are written as `.npy` files, and loaded here.
#
# I'll assume some working knowledge of python/numpy etc. in this post. First though, if TLDR here is the final interactive PCA plot based on [phase 1](https://www.nature.com/articles/nature24995) of the Anopheles gambiae 1000 genomes [project](https://www.malariagen.net/projects/ag1000g).

# %%
from IPython.display import HTML

# %%
HTML(filename="pca_plots.html")
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Plot</title>
#
#
#
#
#         <link rel="stylesheet" href="https://cdn.pydata.org/bokeh/release/bokeh-0.13.0.min.css" type="text/css" />
#
#
#
#         <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-0.13.0.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#             <div class="bk-root" id="df12854b-d6c9-443c-a5c5-5992016fa605"></div>
#
#
#
#
#         <script type="application/json" id="5b45b63c-ffec-400e-b145-35d05df27868">
#           {"e7d92e80-ac9c-433b-b9ea-4a7d8d6b42ab":{"roots":{"references":[{"attributes":{"data_source":{"id":"064c96de-b4d2-4dab-b96a-9169a0880456","type":"ColumnDataSource"},"glyph":{"id":"019083b3-7110-4799-9065-0939e387edf7","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"45958803-9c90-4178-a07b-b019ebd6348d","type":"Circle"},"selection_glyph":null,"view":{"id":"9ea7528f-b28e-408d-a733-3759b77e3507","type":"CDSView"}},"id":"70e1ca94-b8ca-4d75-8826-78021d6b9d7b","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":""},"id":"f60c0b70-bf21-46a0-a040-01369466905e","type":"Title"},{"attributes":{},"id":"6a0af308-79e1-4514-8557-d8c359020a03","type":"UnionRenderers"},{"attributes":{"source":{"id":"1fa498e2-e93a-4641-bb9e-7458abb34fbb","type":"ColumnDataSource"}},"id":"d477d7ce-1ecf-41e8-b5e0-4ee0439cfb9f","type":"CDSView"},{"attributes":{"source":{"id":"0e6de9d3-efd5-43f7-b624-f0d6ffd15447","type":"ColumnDataSource"}},"id":"857a4b32-bce4-4819-98d7-e357511823dc","type":"CDSView"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":0.5},"size":{"units":"screen","value":6},"x":{"field":"x"},"y":{"field":"y"}},"id":"9b4884c3-11ab-48e2-89a4-737c31c68e5c","type":"Circle"},{"attributes":{},"id":"bed650b4-8b04-477c-af57-d7ef4bcac072","type":"Selection"},{"attributes":{},"id":"86ed9463-9c35-4a30-a07e-9956779a2dc2","type":"Selection"},{"attributes":{"data_source":{"id":"ef2eacfd-eee0-4864-8e3f-50a572543cd3","type":"ColumnDataSource"},"glyph":{"id":"ce08ce8d-3f8c-4f4a-99b8-809444d87743","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"33550138-ea11-4302-9875-f5c09c7cbff4","type":"Circle"},"selection_glyph":null,"view":{"id":"66300eba-b051-4a91-97b7-5520f19e2db2","type":"CDSView"}},"id":"271c2a73-5578-4b87-a30e-f7c901b88f8e","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":0.5},"size":{"units":"screen","value":6},"x":{"field":"x"},"y":{"field":"y"}},"id":"6a848862-9474-41e9-b5ab-a88681e092dc","type":"Circle"},{"attributes":{},"id":"25a855c6-09de-437e-a3b3-92edb320a74b","type":"UnionRenderers"},{"attributes":{},"id":"02357ff1-2a38-4f51-9f0a-f946e18290d8","type":"UnionRenderers"},{"attributes":{"data_source":{"id":"c1525e49-5fa8-4b52-b76c-5944a63488c8","type":"ColumnDataSource"},"glyph":{"id":"14f5ae51-c660-44d8-8403-91530cfe48cb","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"6a848862-9474-41e9-b5ab-a88681e092dc","type":"Circle"},"selection_glyph":null,"view":{"id":"699fdc24-7bd1-4246-8287-b90619c57f7d","type":"CDSView"}},"id":"1db0f2ad-e291-4d50-b050-16b5ca90b86b","type":"GlyphRenderer"},{"attributes":{},"id":"975758de-1d7f-4fcc-a0d8-c892ef4c7a31","type":"Selection"},{"attributes":{"data_source":{"id":"fe509eb2-32fc-41fd-a388-a309851e10fd","type":"ColumnDataSource"},"glyph":{"id":"d656e3e6-0d7e-4de5-9109-8e3698298276","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"aef1bd45-4124-4b2a-82d1-11e33d1f7e9e","type":"Circle"},"selection_glyph":null,"view":{"id":"75af8b23-0fc8-4a88-904b-e9ffe51b7628","type":"CDSView"}},"id":"1bbbc15c-afc0-4b85-82e6-3d1c9d73412e","type":"GlyphRenderer"},{"attributes":{"source":{"id":"ef2eacfd-eee0-4864-8e3f-50a572543cd3","type":"ColumnDataSource"}},"id":"66300eba-b051-4a91-97b7-5520f19e2db2","type":"CDSView"},{"attributes":{"data_source":{"id":"ded136cf-b904-4d78-ad8f-d3f21bcb603f","type":"ColumnDataSource"},"glyph":{"id":"77b9df03-c2cc-418e-b5cf-a603d664374a","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a0aa35b0-7790-4f1a-853b-cc4293ff23f6","type":"Circle"},"selection_glyph":null,"view":{"id":"b7270d71-e059-4cf2-b857-f7df00e16b5c","type":"CDSView"}},"id":"4125992b-e091-4b08-9fd4-7293851a4ad4","type":"Glyp ...

# %%
import numpy as np

# %%
# load some PCA data
coordinates = np.load("3L_10000000_30000000.coords.npy")
coordinates.shape
# Out:
# (765, 10)

# %%
# load the PVE data
pve = np.load("3L_10000000_30000000.pve.npy")
pve
# Out:
# array([ 0.01200335,  0.01070692,  0.00852672,  0.00606027,  0.00494645,
#         0.00357033,  0.00341437,  0.00317344,  0.00313177,  0.00299404])

# %% [markdown]
# We need some metadata, so we can label our points accordingly. I know that the order of this dataframe corresponds to the PCA coordinates, it's important to check this!
#
# Here we are interested in the sample ID, the population label, country and year of collection.

# %%
import pandas as pd

# %%
df = pd.read_table(
    "/kwiat/vector/ag1000g/release/phase1.AR3/samples/samples.meta.txt",
    index_col=0)[['ox_code', 'population', 'country', 'year']]

# %%
df.head()
# Out:
#         ox_code population       country  year
# index
# 0      AB0085-C        BFS  Burkina Faso  2012
# 1      AB0087-C        BFM  Burkina Faso  2012
# 2      AB0088-C        BFM  Burkina Faso  2012
# 3      AB0089-C        BFM  Burkina Faso  2012
# 4      AB0090-C        BFM  Burkina Faso  2012

# %% [markdown]
# We define some colours to use for the different populations

# %%
pop_colours = {
    'BFM': '#FF0000',
    'GAS': '#008000',
    'GNS': '#00FFFF',
    'UGS': '#90EE90',
    'GWA': '#FFA500',
    'AOM': '#8B0000',
    'BFS': '#1E90FF',
    'KES': '#808080',
    'CMS': '#0000FF',
}

# %%
# imports required for `bokeh`
from bokeh.plotting import figure, show, ColumnDataSource, output_file
from bokeh.layouts import gridplot

# %% [markdown]
# This is the main function that does most of the plotting work. It takes in the coordinates, the PVE, the principal components you wish to plot, a figure object (explained later) and a list of populations to show.
#
#
# The only fiddly bit is that a `bokeh` plot expects a _source_, which should be tabular. All values that you wish to annotate with must be in this table. This is why I create a copy of my metadata frame and add in the relevant principal components as `x` and `y`.
#
# `bokeh` expects hex colors, so we use `mpl.colors` to convert from the above.

# %%
import matplotlib as mpl

def plot_pca_coords(coords, pve, pc1, pc2, fig, populations):

    x = coords[:, pc1]
    y = coords[:, pc2]
    
    qdf = df.copy()
    qdf["x"] = x
    qdf["y"] = y
    
    for pop in populations:
        
        source = ColumnDataSource(
            data=qdf.query("population == @pop"))
        
        fig.circle(
            'x', 'y', 
            source=source,
            line_color='black',
            line_width=0.5,
            size=6,
            fill_color=mpl.colors.rgb2hex(pop_colours[pop]))
    
    fig.xaxis.axis_label = 'PC {0} ({1:.2f}%)'.format(
        pc1 + 1, 100 * pve[pc1])
    
    fig.yaxis.axis_label = 'PC {0} ({1:.2f}%)'.format(
        pc2 + 1, 100 * pve[pc2])
    
    return fig

# %%
components = np.array(range(8)).reshape((2, 2, 2)).tolist()

# %%
# This defines what is displayed when the mouse hovers over a point.
# The @ values correspond to values in the table.
TOOLTIPS = [
    ("ox_code", "@ox_code"),
    ("population", "@population"),
    ("collection year", "@year"),
    ("(x, y)", "($x, $y)"),]

# %% [markdown]
# The below code sets up a bokeh grid to display multiple PCA components at a time.
# If you just want to make a single figure, you just need to create the `figure` and pass it to the `plot_pca_coords` function.

# %%
output_file("pca_plots.html")
grid = []

for row in components:
    
    l = []
    
    for (c1, c2) in row:

        p = figure(plot_width=400, plot_height=400, tooltips=TOOLTIPS)
        l.append(
            plot_pca_coords(
                coordinates, pve, c1, c2, p,
                pop_colours.keys()))
        
    grid.append(l)

col = gridplot(grid)
show(col)

# %% [markdown]
# And that's it! Check out the box zoom, I find that super useful.

# %%
HTML(filename="pca_plots.html")
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Plot</title>
#
#
#
#
#         <link rel="stylesheet" href="https://cdn.pydata.org/bokeh/release/bokeh-0.13.0.min.css" type="text/css" />
#
#
#
#         <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-0.13.0.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#             <div class="bk-root" id="bd0da49d-8615-4207-99b2-3f4c41d19da6"></div>
#
#
#
#
#         <script type="application/json" id="e1787024-080e-43c5-bc9f-cd2950345824">
#           {"4f52fe04-d69b-46c4-8da4-27da38b47f07":{"roots":{"references":[{"attributes":{"data_source":{"id":"a38f07fc-e13b-4285-8612-171bc5652694","type":"ColumnDataSource"},"glyph":{"id":"e688b065-2b19-4c23-bc1d-9defa00eb322","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"cf323086-b093-4466-ac27-eff7fb1ff2c9","type":"Circle"},"selection_glyph":null,"view":{"id":"2d2bdc54-5834-4d23-b56a-da47e8490992","type":"CDSView"}},"id":"a03559f9-fb5a-4f85-981c-31fe22685cb4","type":"GlyphRenderer"},{"attributes":{"source":{"id":"a38f07fc-e13b-4285-8612-171bc5652694","type":"ColumnDataSource"}},"id":"2d2bdc54-5834-4d23-b56a-da47e8490992","type":"CDSView"},{"attributes":{"fill_color":{"value":"#008000"},"line_width":{"value":0.5},"size":{"units":"screen","value":6},"x":{"field":"x"},"y":{"field":"y"}},"id":"f