# %%
import numpy as np

# %%
from bokeh.plotting import figure, show, ColumnDataSource, output_file
from bokeh.layouts import gridplot

# %%
# load some PCA data
coordinates = np.load("3L_10000000_30000000.coords.npy")
coordinates.shape
# Out:
# (765, 10)

# %%
pve = np.load("3L_10000000_30000000.pve.npy")
pve
# Out:
# array([ 0.01200335,  0.01070692,  0.00852672,  0.00606027,  0.00494645,
#         0.00357033,  0.00341437,  0.00317344,  0.00313177,  0.00299404])

# %%
import pandas as pd

# %%
df = pd.read_table(
    "/kwiat/vector/ag1000g/release/phase1.AR3/samples/samples.meta.txt",
    index_col=0)[['ox_code', 'population', 'country', 'year']]

# %%
df.head()
# Out:
#         ox_code population       country  year
# index
# 0      AB0085-C        BFS  Burkina Faso  2012
# 1      AB0087-C        BFM  Burkina Faso  2012
# 2      AB0088-C        BFM  Burkina Faso  2012
# 3      AB0089-C        BFM  Burkina Faso  2012
# 4      AB0090-C        BFM  Burkina Faso  2012

# %%
pop_colours = {
    'BFM': '#FF0000',
    'GAS': '#008000',
    'GNS': '#00FFFF',
    'UGS': '#90EE90',
    'GWA': '#FFA500',
    'AOM': '#8B0000',
    'BFS': '#1E90FF',
    'KES': '#808080',
    'CMS': '#0000FF',
}

# %%
import matplotlib as mpl
def plot_pca_coords(coords, pve, pc1, pc2, fig, populations):

    x = coords[:, pc1]
    y = coords[:, pc2]
    
    qdf = df.copy()
    qdf["x"] = x
    qdf["y"] = y
    
    for pop in populations:
        
        source = ColumnDataSource(
            data=qdf.query("population == @pop"))
        
        try:
            q = mpl.colors.rgb2hex(pop_colours[pop])
        except ValueError:
            print("X")
            q = mpl.colors.to_hex(pop_colours[pop])
        
        fig.circle(
            'x', 'y', 
            source=source,
            line_color='black',
            line_width=0.5,
            size=6,
            fill_color=q)
    
    fig.xaxis.axis_label = 'PC {0} ({1:.2f}%)'.format(
        pc1 + 1, 100 * pve[pc1])
    
    fig.yaxis.axis_label = 'PC {0} ({1:.2f}%)'.format(
        pc2 + 1, 100 * pve[pc2])
    
    return fig

# %%
components = np.array(range(8)).reshape((2, 2, 2)).tolist()

# %%
TOOLTIPS = [
    ("ox_code", "@ox_code"),
    ("population", "@population"),
    ("collection year", "@year"),
    ("(x, y)", "($x, $y)"),]

# %%
output_file("pca_plots.html")
grid = []

for row in components:
    
    l = []
    
    for (c1, c2) in row:

        p = figure(plot_width=400, plot_height=400, tooltips=TOOLTIPS)
        l.append(
            plot_pca_coords(
                coordinates, pve, c1, c2, p,
                pop_colours.keys()))
        
    grid.append(l)

col = gridplot(grid)
show(col)

# %%
from IPython.display import HTML

# %%
HTML(filename="pca_plots.html")
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Plot</title>
#
#
#
#
#         <link rel="stylesheet" href="https://cdn.pydata.org/bokeh/release/bokeh-0.13.0.min.css" type="text/css" />
#
#
#
#         <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-0.13.0.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#             <div class="bk-root" id="4c0e9a5d-a3f5-4f8b-9965-8725ee567ded"></div>
#
#
#
#
#         <script type="application/json" id="a65252d8-952d-40ac-bcfa-d01cc814ed06">
#           {"0cf64858-fee3-4882-8276-29b1419ad237":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":0.5},"size":{"units":"screen","value":6},"x":{"field":"x"},"y":{"field":"y"}},"id":"1d588252-a677-4ad9-afcd-35aefe190afc","type":"Circle"},{"attributes":{},"id":"d6803f80-ef95-4673-8ac1-dababda82007","type":"UnionRenderers"},{"attributes":{"fill_color":{"value":"#ffa500"},"line_width":{"value":0.5},"size":{"units":"screen","value":6},"x":{"field":"x"},"y":{"field":"y"}},"id":"a2419fde-0b8d-4025-9a6f-f96ea9de4c11","type":"Circle"},{"attributes":{},"id":"315a296d-83a4-43bb-95c4-d3a776601292","type":"UnionRenderers"},{"attributes":{"fill_color":{"value":"#8b0000"},"line_width":{"value":0.5},"size":{"units":"screen","value":6},"x":{"field":"x"},"y":{"field":"y"}},"id":"b976b13c-53b1-4395-a4f6-61ffb413ba7c","type":"Circle"},{"attributes":{},"id":"44ba5cc9-85e9-4667-8d04-a95e7423745c","type":"BasicTickFormatter"},{"attributes":{},"id":"bcb896d3-50dd-49f3-8242-5e69258342a6","type":"UnionRenderers"},{"attributes":{},"id":"5962b0c6-8c46-46d6-bc48-428933fe0770","type":"Selection"},{"attributes":{},"id":"99d5bc6f-6a48-4158-ac07-a15cf8309970","type":"UnionRenderers"},{"attributes":{"fill_color":{"value":"#ff0000"},"line_width":{"value":0.5},"size":{"units":"screen","value":6},"x":{"field":"x"},"y":{"field":"y"}},"id":"6707b5f0-5566-43a1-9c13-81fd1f67b564","type":"Circle"},{"attributes":{"data_source":{"id":"ce72bfd9-1ee0-4727-82e5-8ff99d46820d","type":"ColumnDataSource"},"glyph":{"id":"a2419fde-0b8d-4025-9a6f-f96ea9de4c11","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1d588252-a677-4ad9-afcd-35aefe190afc","type":"Circle"},"selection_glyph":null,"view":{"id":"afce7c22-f741-43fc-9907-a8b59cc1b79e","type":"CDSView"}},"id":"777cae11-cb64-4d85-856b-f60abbdd2071","type":"GlyphRenderer"},{"attributes":{},"id":"a458d8d3-7b2f-4c30-a6bd-ce93d7126c5c","type":"Selection"},{"attributes":{},"id":"59386c09-b442-4ebc-a3ee-4e88a9d855e0","type":"UnionRenderers"},{"attributes":{"callback":null,"data":{"country":["Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda","Uganda"],"index":[150,151,152,153,154,155,156,157,158,159,160,161,162,163,164,165,166,167,168,169,170,171,172,173,174,175,176,177,178,179,180,181,182,183,184,185,186,187,188,189,190,191,192,193,194,195,196,197,198,199,200,201,202,203,204,205,206,207,208,209,210,211,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,237,238,239,240,241,242,243,244,245,246,247,248,249,250,251,252],"ox_code":["AC0090-C","AC0091-C","AC0092-C","AC0093-C","AC0094-C","AC0095-C","AC0096-C","AC0097-C","AC0098-C","AC0099-C","AC0100-C","AC0101-C","AC0102-C","AC0103-C","AC0104-C","AC0106-C","AC0107-C","AC0108-C","AC0109-C","AC0110-C","AC0111-C","AC0112-C","AC0113-C","AC0114-C","AC0115-C","AC0116-C","AC0117-C","AC0118-C","AC0119-C","AC0120-C","AC0121-C","AC0122-C","AC0123-C","AC0124-C","AC0125-C","AC0126-C","AC0127-C","AC0128-C","AC0129-C","AC0130-C","AC0131-C","AC01 ...
